# %%
import pandas as pd
import json
from pandas.io.json import json_normalize

with open('E:/fiver projects/schedule-optimization/test/scenario1/fixtures/workplan.json', 'rb') as f:
    workplan_dict = json.load(f)[0]
    
workplan_dict
# Out:
# {'id': 1,
#  'name': 'Workplan scenario 1',
#  'type': 'Fill users to contracted hours',
#  'users': [{'id': 1001,
#    'email': 'ts1usera@test.com',
#    'location': {'id': 1},
#    'seniority': 6,
#    'businessRoles': [{'id': 23}, {'id': 24}],
#    'team': {'id': 108, 'name': 'Team for Scenario 1'},
#    'timezone': 'Australia/Sydney',
#    'contract': {'employmentCategory': 'Full Time',
#     'minimumTimeBetweenShiftsMins': 720,
#     'paidHours': {'type': 'Fixed',
#      'period': {'value': 1, 'unit': 'weeks'},
#      'paidMinutesMin': 2400,
#      'paidMinutesMax': 2400},
#     'numberOfShifts': {'type': 'Fixed',
#      'period': {'value': 1, 'unit': 'weeks'},
#      'numberOfShiftsMin': 5,
#      'numberOfShiftsMax': 5},
#     'maxConsecutiveShifts': 7},
#    'shiftHistory': [{'id': 'mnhsgdfcjkygwsl',
#      'startTime': '2019-12-30T21:00:00Z',
#      'endTime': '2019-12-30T21:00:00Z',
#      'paidMinutes': 240,
#      'workloadTaskId': 12345,
# ...

# %%
# users =json_normalize(data=json_workplan['users'])
# users = users.drop(['email','team.name','timezone'], axis=1)

# # Accessing users by conditional filtering
# user = users.loc[users['id'] == 1001]
# user
# user["availableDays"][0][0]

# %%
for user in workplan_dict["users"]:
    print(user)
# Out:
# {'id': 1001, 'email': 'ts1usera@test.com', 'location': {'id': 1}, 'seniority': 6, 'businessRoles': [{'id': 23}, {'id': 24}], 'team': {'id': 108, 'name': 'Team for Scenario 1'}, 'timezone': 'Australia/Sydney', 'contract': {'employmentCategory': 'Full Time', 'minimumTimeBetweenShiftsMins': 720, 'paidHours': {'type': 'Fixed', 'period': {'value': 1, 'unit': 'weeks'}, 'paidMinutesMin': 2400, 'paidMinutesMax': 2400}, 'numberOfShifts': {'type': 'Fixed', 'period': {'value': 1, 'unit': 'weeks'}, 'numberOfShiftsMin': 5, 'numberOfShiftsMax': 5}, 'maxConsecutiveShifts': 7}, 'shiftHistory': [{'id': 'mnhsgdfcjkygwsl', 'startTime': '2019-12-30T21:00:00Z', 'endTime': '2019-12-30T21:00:00Z', 'paidMinutes': 240, 'workloadTaskId': 12345, 'shiftTemplateId': 'usingOldTemplateAndShouldNotBePartOfRotation'}], 'availableDays': [{'from': '2020-03-22T20:00:00.000Z', 'to': '2020-03-23T12:00:00.000Z'}, {'from': '2020-03-23T20:00:00.000Z', 'to': '2020-03-24T12:00:00.000Z'}, {'from': '2020-03-24T20:00:00.000Z', '
# ...
